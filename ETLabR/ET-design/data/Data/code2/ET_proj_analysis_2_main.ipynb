# %%
# ET_proj_analysis_1_main.ipynb
# 数据处理主程序
# 仅提供一个处理流程的示例

# 导入必要的库
import analysis_2_function as a2f # 特别提醒：数据集要跟main和这个文件在同一文件夹下
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 处理数据（给出各个shutter的散点关系图）
shutter_name = 'shutter6'
outcome = a2f.data_integration(shutter_name)
a2f.main_plot(outcome, name=shutter_name)
